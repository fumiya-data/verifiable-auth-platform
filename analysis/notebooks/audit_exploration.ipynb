# %% [markdown]
# # Audit Exploration
#
# This notebook is a starting point for inspecting audit event distributions from the engine observability contract.

# %%
from pathlib import Path
import json

root = Path.cwd().resolve().parents[0]
sample = root / "observability" / "audit" / "sample-events.json"
payload = json.loads(sample.read_text(encoding="utf-8"))
payload["data"]["events"]
