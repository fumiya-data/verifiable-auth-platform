# %% [markdown]
# # Metrics Exploration
#
# This notebook is a starting point for inspecting derived metrics emitted by the engine.

# %%
from pathlib import Path
import json

root = Path.cwd().resolve().parents[0]
sample = root / "observability" / "metrics" / "sample-metrics.json"
payload = json.loads(sample.read_text(encoding="utf-8"))
payload["data"]
